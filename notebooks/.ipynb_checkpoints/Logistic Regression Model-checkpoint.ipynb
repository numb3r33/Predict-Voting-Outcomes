# %%
# %matplotlib inline

import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
import seaborn as sns

import missingno as msno

from sklearn.manifold import TSNE
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import accuracy_score
from sklearn.linear_model import LogisticRegression, RandomizedLogisticRegression
from sklearn.cross_validation import StratifiedKFold, train_test_split, cross_val_score

import warnings
warnings.filterwarnings('ignore')

# %%
# load files
train = pd.read_csv('../data/train2016.csv')
test  = pd.read_csv('../data/train2016.csv')
sub   = pd.read_csv('../data/sampleSubmission2016.csv')

# %%
# concat train and test which would make it easy to generate features
data = pd.concat((train, test))

# %% [markdown]
# ```
# Visulize missing values using this utitily called missingno
# ```

# %%
# visualize missing values in the training set
msno.matrix(train.sample(250))

# %%
# visualize missing value in the test set
msno.matrix(test.sample(250))

# %% [markdown]
# ** Lots of missing values, let's see if number of missing values have any predictive power. **

# %%
data['missing_val_count'] = data.apply(lambda x: pd.isnull(x).sum(), axis=1)

# %%
sns.kdeplot(data[(data.Party.notnull()) & (data.Party == 'Democrat')]['missing_val_count'], label='Democrat')
sns.kdeplot(data[(data.Party.notnull()) & (data.Party != 'Democrat')]['missing_val_count'], label='Republican');

# %% [markdown]
# ** t-sne clustering to see if there are any obviious clusters **

# %%
# for tsne to work first
# 1. Impute missing values
# 2. Encode categorical values

def fill_missing_values(df):
    df = df.copy()
    
    for cat in df.columns:
        if df[cat].isnull().any():
            if df[cat].dtype == 'object':
                df[cat] = df[cat].fillna('-999')
            else:
                df[cat] = df[cat].fillna(-9999)
    return df

def encode_cat_features(df):
    df = df.copy()
    
    for cat in df.columns:
        if cat == 'Party':
            continue
        if df[cat].dtype == 'object':
            lbl = LabelEncoder()
            
            lbl.fit(df[cat])
            df[cat] = lbl.transform(df[cat])
    
    return df

# %%
train_ = fill_missing_values(train)
train_ = encode_cat_features(train_)

# %%
DROP_FEATURES = ['USER_ID', 'PARTY']

features = [col for col in train_.columns if col not in DROP_FEATURES]

# %%
print('Shape of the dataset ', train_[features].shape)
# Out:
# Shape of the dataset  (5568, 107)

# %% [markdown]
# #### Visualize this high dimensional data

# %% [markdown]
# ```
# Perplexity: How to balance attention between local and global aspects of your data ?
# The performance of SNE is fairly robust to changes in the perplexity, and typical values are between 5 and 50.
# ```

# %%
tsne = TSNE(n_components=2, perplexity=5.0, random_state=12386)
Y = tsne.fit_transform(train_[features])

plt.scatter(Y[:, 0], Y[:, 1], c=(train.Party), cmap=plt.cm.Spectral);

# %%
tsne = TSNE(n_components=2, perplexity=15.0, random_state=12386)
Y = tsne.fit_transform(train_[features])

plt.scatter(Y[:, 0], Y[:, 1], c=(train.Party), cmap=plt.cm.Spectral);

# %%
tsne = TSNE(n_components=2, perplexity=30.0, random_state=12386)
Y = tsne.fit_transform(train_[features])

plt.scatter(Y[:, 0], Y[:, 1], c=(train.Party), cmap=plt.cm.Spectral);

# %%
tsne = TSNE(n_components=2, perplexity=50.0, random_state=12386)
Y = tsne.fit_transform(train_[features])

plt.scatter(Y[:, 0], Y[:, 1], c=(train.Party), cmap=plt.cm.Spectral);

# %% [markdown]
# ```
# Create variable called Age which is the difference of YOB from 2016 and then label them into different categories.
# ```

# %%
def create_age(yob):
    if yob != -9999:
        return 2016 - yob
    else:
        return -9999

def create_age_mapping(age):
    if age < 17:
        return 0
    elif age >= 18 and age < 25:
        return 1
    elif age >= 25 and age < 35:
        return 2
    elif age >= 35 and age < 50:
        return 3
    elif age >= 50 and age < 65:
        return 4
    elif age >= 65:
        return 5
    else:
        return -9999

# %%
data['Age'] = data.YOB.map(create_age)
data['Age_Mapping'] = data.Age.map(create_age_mapping)

# %%
data.Age_Mapping.value_counts()
# Out:
#  3       2902
#  1       2762
#  2       2458
#  4       1416
# -9999     846
#  5        656
#  0         96
# Name: Age_Mapping, dtype: int64

# %%
pd.crosstab(data[data.Party.notnull()].Age_Mapping, data[data.Party.notnull()].Party, margins=True)
# Out:
# Party        Democrat  Republican    All
# Age_Mapping
# -9999             430         416    846
# 0                  44          52     96
# 1                1462        1300   2762
# 2                1314        1144   2458
# 3                1540        1362   2902
# 4                 734         682   1416
# 5                 378         278    656
# All              5902        5234  11136

# %%
# concat train and test datasets

data = fill_missing_values(data)
data = encode_cat_features(data)

# %%
# consider only this feature age mapping and see if it is of any importance
mask = (data.Party.notnull())

# features = ['Age_Mapping', 'Gender', 'HouseholdStatus',\
#             'EducationLevel']\
features = data.columns.drop(['USER_ID', 'Party'])

X = data.loc[mask, features]
y = data.Party

Xtest = data.loc[(data.Party.isnull()), features]

# %%
Xtest
# Out:
# Empty DataFrame
# Columns: [EducationLevel, Gender, HouseholdStatus, Income, Q100010, Q100562, Q100680, Q100689, Q101162, Q101163, Q101596, Q102089, Q102289, Q102674, Q102687, Q102906, Q103293, Q104996, Q105655, Q105840, Q106042, Q106272, Q106388, Q106389, Q106993, Q106997, Q107491, Q107869, Q108342, Q108343, Q108617, Q108754, Q108855, Q108856, Q108950, Q109244, Q109367, Q110740, Q111220, Q111580, Q111848, Q112270, Q112478, Q112512, Q113181, Q113583, Q113584, Q113992, Q114152, Q114386, Q114517, Q114748, Q114961, Q115195, Q115390, Q115602, Q115610, Q115611, Q115777, Q115899, Q116197, Q116441, Q116448, Q116601, Q116797, Q116881, Q116953, Q117186, Q117193, Q118117, Q118232, Q118233, Q118237, Q118892, Q119334, Q119650, Q119851, Q120012, Q120014, Q120194, Q120379, Q120472, Q120650, Q120978, Q121011, Q121699, Q121700, Q122120, Q122769, Q122770, Q122771, Q123464, Q123621, Q124122, Q124742, Q96024, Q98059, Q98078, Q98197, Q98578, ...]
# Index: []
#
# [0 rows x 109 columns]

# %% [markdown]
# ** Split into training and test sets **

# %%
Xtr, Xte, ytr, yte = train_test_split(X, y, stratify=y, test_size=0.2, random_state=12386)

# %%
est = LogisticRegression()
skf = StratifiedKFold(ytr, n_folds=5, random_state=123)

cv_scores = cross_val_score(est, Xtr, ytr, scoring='accuracy', cv=skf, n_jobs=-1)

# %%
print('Mean cv score: %f and std: %f'%(cv_scores.mean(), cv_scores.std()))
# Out:
# Mean cv score: 0.608553 and std: 0.007996

# %% [markdown]
# ** Check score on the holdout set **

# %%
est.fit(Xtr, ytr)
yhat = est.predict(Xte)

print('Accuracy on the hold out set: %f'%(accuracy_score(yte, yhat)))
# Out:
# Accuracy on the hold out set: 0.611311

# %% [markdown]
# ** Confidence Intervals **

# %% [markdown]
# ```
# One way to get confidence intervals is to bootstrap your data, say, B times and fit logistic regression models mi to the dataset Bi for i=1,2,...,Bi=1,2,...,B. This gives you a distribution for the parameters you are estimating, from which you can find the confidence intervals.
# ```

# %%
def get_confidence_intervals(est, X, y):
    skf = StratifiedKFold(y, n_folds=5, random_state=133)
#  ['EducationLevel', 'Gender', 'HouseholdStatus', 'Income', 'Q100680', 'Q100689', 'Q101162', 'Q101163', 'Q101596', 'Q102089', 'Q102289', 'Q102687', 'Q102906', 'Q104996', 'Q105655', 'Q106272', 'Q106388', 'Q106993', 'Q106997', 'Q107869', 'Q108342', 'Q108754', 'Q108855', 'Q108856', 'Q109244', 'Q109367', 'Q110740', 'Q111220', 'Q111580', 'Q111848', 'Q112512', 'Q113181', 'Q113583', 'Q113992', 'Q114517', 'Q114748', 'Q114961', 'Q115195', 'Q115390', 'Q115602', 'Q115610', 'Q115611', 'Q115777', 'Q115899', 'Q116441', 'Q116448', 'Q116601', 'Q116881', 'Q116953', 'Q117186', 'Q118117', 'Q118237', 'Q119334', 'Q119851', 'Q120012', 'Q120014', 'Q120194', 'Q120379', 'Q120472', 'Q120650', 'Q121699', 'Q121700', 'Q122120', 'Q122770', 'Q123621', 'Q124122', 'Q124742', 'Q98059', 'Q98078', 'Q98197', 'Q98869', 'Q99480', 'Q99581', 'Q99716', 'missing_val_count', 'Age_Mapping']

# %%
est.fit(Xtr[features[selected_features]], ytr)
yhat = est.predict(Xte[features[selected_features]])
print('Accuracy after feature selection: %f'%(accuracy_score(yte, yhat)))
# Out:
# Accuracy after feature selection: 0.612208

# %% [markdown]
# ** Full Training **

# %%
Xtest
# Out:
# Empty DataFrame
# Columns: [EducationLevel, Gender, HouseholdStatus, Income, Q100010, Q100562, Q100680, Q100689, Q101162, Q101163, Q101596, Q102089, Q102289, Q102674, Q102687, Q102906, Q103293, Q104996, Q105655, Q105840, Q106042, Q106272, Q106388, Q106389, Q106993, Q106997, Q107491, Q107869, Q108342, Q108343, Q108617, Q108754, Q108855, Q108856, Q108950, Q109244, Q109367, Q110740, Q111220, Q111580, Q111848, Q112270, Q112478, Q112512, Q113181, Q113583, Q113584, Q113992, Q114152, Q114386, Q114517, Q114748, Q114961, Q115195, Q115390, Q115602, Q115610, Q115611, Q115777, Q115899, Q116197, Q116441, Q116448, Q116601, Q116797, Q116881, Q116953, Q117186, Q117193, Q118117, Q118232, Q118233, Q118237, Q118892, Q119334, Q119650, Q119851, Q120012, Q120014, Q120194, Q120379, Q120472, Q120650, Q120978, Q121011, Q121699, Q121700, Q122120, Q122769, Q122770, Q122771, Q123464, Q123621, Q124122, Q124742, Q96024, Q98059, Q98078, Q98197, Q98578, ...]
# Index: []
#
# [0 rows x 109 columns]

# %%
# full training
est.fit(X[features[selected_features]], y)
predictions = est.predict(Xtest[features[selected_features]])
prediction_labels = map(lambda x: 'Democrat' if x == 1 else 'Republican', predictions)
sub.to_csv('../submissions/feature_sel_logistic_regression.csv', index=False)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-69-57006cb9f920> in <module>()
#       1 # full training
#       2 est.fit(X[features[selected_features]], y)
# ----> 3 predictions = est.predict(Xtest[features[selected_features]])
#       4 prediction_labels = map(lambda x: 'Democrat' if x == 1 else 'Republican', predictions)
#       5 sub.to_csv('../submissions/feature_sel_logistic_regression.csv', index=False)
#
# /home/abhishek/anaconda3/lib/python3.5/site-packages/sklearn/linear_model/base.py in predict(self, X)
#     266             Predicted class label per sample.
#     267         """
# --> 268         scores = self.decision_function(X)
#     269         if len(scores.shape) == 1:
#     270             indices = (scores > 0).astype(np.int)
#
# /home/abhishek/anaconda3/lib/python3.5/site-packages/sklearn/linear_model/base.py in decision_function(self, X)
#     242                                  "yet" % {'name': type(self).__name__})
#     243
# --> 244         X = check_array(X, accept_sparse='csr')
#     245
#     246         n_features = self.coef_.shape[1]
#
# /home/abhishek/anaconda3/lib/python3.5/site-packages/sklearn/utils/validation.py in check_array(array, accept_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, warn_on_dtype, estimator)
#     405                              " minimum of %d is required%s."
#     406                              % (n_samples, shape_repr, ensure_min_samples,
# --> 407                                 context))
#     408
#     409     if ensure_min_features > 0 and array.ndim == 2:
#
# ValueError: Found array with 0 sample(s) (shape=(0, 76)) while a minimum of 1 is required.
